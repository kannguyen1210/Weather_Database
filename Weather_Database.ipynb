# %%
# Import dependenncies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
from citipy import citipy
from datetime import datetime
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create API URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | touba
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | pochutla
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | dongzhen
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | ulcinj
# Processing Record 14 of Set 1 | hovd
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 18 of Set 1 | esso
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | vestmannaeyjar
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | saint-leu
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | catia la mar
# Processing Record 33 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | mount gambier
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | nikel
# Processing Record 42 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | gilgit
# Processing Record 47 of Set 1 | san rafael abajo
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | ancud
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | artyom
# Processing Record 6 of Set 2 | hukuntsi
# Processing Record 7 of Set 2 | tezu
# Processing Record 8 of Set 2 | da nang
# Processing Record 9 of Set 2 | kodinsk
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | ust-ilimsk
# Processing Record 12 of Set 2 | altay
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | port blair
# Processing Record 15 of Set 2 | malard
# Processing Record 16 of Set 2 | aklavik
# Processing Record 17 of Set 2 | forestville
# Processing Record 18 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | padina
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | saint pete beach
# Processing Record 24 of Set 2 | ambilobe
# Processing Record 25 of Set 2 | whitehorse
# Processing Record 26 of Set 2 | ganzhou
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | talcahuano
# Processing Record 30 of Set 2 | bulgan
# Processing Record 31 of Set 2 | labuhan
# Processing Record 32 of Set 2 | kavaratti
# Processing Record 33 of Set 2 | smithers
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | apatity
# Processing Record 38 of Set 2 | mount darwin
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | pisco
# Processing Record 44 of Set 2 | aykhal
# Processing Record 45 of Set 2 | bathsheba
# Processing Record 46 of Set 2 | alice springs
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | ambositra
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | fort-shevchenko
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | gopalur
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | wattegama
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | waipawa
# Processing Record 10 of Set 3 | belluno
# Processing Record 11 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 3 | husavik
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | sisimiut
# Processing Record 17 of Set 3 | edd
# Processing Record 18 of Set 3 | maraba
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | benghazi
# Processing Record 21 of Set 3 | oleksandrivka
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | college
# Processing Record 24 of Set 3 | greytown
# Processing Record 25 of Set 3 | marostica
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | dingli
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | gravdal
# Processing Record 31 of Set 3 | bosaso
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | kraksaan
# Processing Record 35 of Set 3 | jinka
# Processing Record 36 of Set 3 | olavarria
# Processing Record 37 of Set 3 | kokopo
# Processing Record 38 of Set 3 | tevaitoa
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | preobrazheniye
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | cam ranh
# Processing Record 43 of Set 3 | karpathos
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | ostrovnoy
# Processing Record 48 of Set 3 | rio de janeiro
# Processing Record 49 of Set 3 | dingle
# Processing Record 50 of Set 3 | vila
# Processing Record 1 of Set 4 | elk point
# Processing Record 2 of Set 4 | springbok
# Processing Record 3 of Set 4 | navahrudak
# Processing Record 4 of Set 4 | deputatskiy
# Processing Record 5 of Set 4 | nuuk
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | myrtle beach
# Processing Record 10 of Set 4 | gat
# Processing Record 11 of Set 4 | wad rawah
# Processing Record 12 of Set 4 | ust-kuyga
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | nanortalik
# Processing Record 15 of Set 4 | bumba
# Processing Record 16 of Set 4 | uniao
# Processing Record 17 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 4 | damphu
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | moree
# Processing Record 21 of Set 4 | santa ana
# Processing Record 22 of Set 4 | kollam
# Processing Record 23 of Set 4 | santo tomas
# Processing Record 24 of Set 4 | bato
# Processing Record 25 of Set 4 | mahibadhoo
# Processing Record 26 of Set 4 | tabuk
# Processing Record 27 of Set 4 | port augusta
# Processing Record 28 of Set 4 | inuvik
# Processing Record 29 of Set 4 | majene
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | flinders
# Processing Record 32 of Set 4 | jieshi
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 4 | darhan
# Processing Record 36 of Set 4 | santa rosalia
# Processing Record 37 of Set 4 | mana
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | ambon
# Processing Record 40 of Set 4 | carpentras
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | udachnyy
# Processing Record 43 of Set 4 | matara
# Processing Record 44 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | keti bandar
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | belchertown
# Processing Record 49 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 50 of Set 4 | trairi
# Processing Record 1 of Set 5 | kirkenaer
# Processing Record 2 of Set 5 | eyl
# Processing Record 3 of Set 5 | plouzane
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | buin
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | mayumba
# Processing Record 8 of Set 5 | yei
# Processing Record 9 of Set 5 | pitimbu
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | kuching
# Processing Record 12 of Set 5 | bereda
# Processing Record 13 of Set 5 | sakakah
# Processing Record 14 of Set 5 | balabac
# Processing Record 15 of Set 5 | andenes
# Processing Record 16 of Set 5 | port moresby
# Processing Record 17 of Set 5 | rognan
# Processing Record 18 of Set 5 | waddan
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | livingston
# Processing Record 21 of Set 5 | zhuanghe
# Processing Record 22 of Set 5 | dzheyrakh
# Processing Record 23 of Set 5 | arica
# Processing Record 24 of Set 5 | igarka
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | san angelo
# Processing Record 27 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | batagay
# Processing Record 31 of Set 5 | bima
# Processing Record 32 of Set 5 | baryatino
# Processing Record 33 of Set 5 | resistencia
# Processing Record 34 of Set 5 | san isidro
# Processing Record 35 of Set 5 | palmer
# Processing Record 36 of Set 5 | katherine
# Processing Record 37 of Set 5 | plettenberg bay
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | banda aceh
# Processing Record 41 of Set 5 | becov
# Processing Record 42 of Set 5 | port macquarie
# Processing Record 43 of Set 5 | falun
# Processing Record 44 of Set 5 | chicama
# Processing Record 45 of Set 5 | shache
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | minna
# Processing Record 48 of Set 5 | kjollefjord
# Processing Record 49 of Set 5 | salinas
# Processing Record 50 of Set 5 | pathein
# Processing Record 1 of Set 6 | ocho rios
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | buala
# Processing Record 7 of Set 6 | taungdwingyi
# Processing Record 8 of Set 6 | dmitriyevka
# Processing Record 9 of Set 6 | batagay-alyta
# Processing Record 10 of Set 6 | mastic beach
# Processing Record 11 of Set 6 | ketchikan
# Processing Record 12 of Set 6 | gayny
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | xining
# Processing Record 15 of Set 6 | kumi
# Processing Record 16 of Set 6 | angoche
# Processing Record 17 of Set 6 | gao
# Processing Record 18 of Set 6 | zhigansk
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | gizo
# Processing Record 21 of Set 6 | saint-augustin
# Processing Record 22 of Set 6 | thompson
# Processing Record 23 of Set 6 | saint-gaudens
# Processing Record 24 of Set 6 | sabang
# Processing Record 25 of Set 6 | marshall
# Processing Record 26 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 6 | komsomolskiy
# Processing Record 29 of Set 6 | hofn
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | hutchinson
# Processing Record 32 of Set 6 | oulu
# Processing Record 33 of Set 6 | monrovia
# Processing Record 34 of Set 6 | goes
# Processing Record 35 of Set 6 | namwala
# Processing Record 36 of Set 6 | zwedru
# Processing Record 37 of Set 6 | arlit
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | vostok
# Processing Record 40 of Set 6 | shimoda
# Processing Record 41 of Set 6 | safonovo
# Processing Record 42 of Set 6 | tura
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | bilma
# Processing Record 45 of Set 6 | blackwater
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | la union
# Processing Record 49 of Set 6 | siocon
# Processing Record 50 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | gombong
# Processing Record 2 of Set 7 | urusha
# Processing Record 3 of Set 7 | tasiilaq
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | fuling
# Processing Record 6 of Set 7 | sorland
# Processing Record 7 of Set 7 | kensington
# Processing Record 8 of Set 7 | chimbote
# Processing Record 9 of Set 7 | tazovskiy
# Processing Record 10 of Set 7 | yar-sale
# Processing Record 11 of Set 7 | agadez
# Processing Record 12 of Set 7 | eureka
# Processing Record 13 of Set 7 | whyalla
# Processing Record 14 of Set 7 | birao
# Processing Record 15 of Set 7 | teguldet
# Processing Record 16 of Set 7 | borkenes
# Processing Record 17 of Set 7 | acajutiba
# Processing Record 18 of Set 7 | truth or consequences
# Processing Record 19 of Set 7 | tsagan aman
# Processing Record 20 of Set 7 | oistins
# Processing Record 21 of Set 7 | rajec
# Processing Record 22 of Set 7 | souillac
# Processing Record 23 of Set 7 | dagana
# Processing Record 24 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 7 | fort frances
# Processing Record 26 of Set 7 | severnyy
# Processing Record 27 of Set 7 | leningradskiy
# Processing Record 28 of Set 7 | salvacion
# Processing Record 29 of Set 7 | bashtanka
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | dera bugti
# Processing Record 32 of Set 7 | ponta grossa
# Processing Record 33 of Set 7 | hambantota
# Processing Record 34 of Set 7 | grindavik
# Processing Record 35 of Set 7 | coquimbo
# Processing Record 36 of Set 7 | bata
# Processing Record 37 of Set 7 | concepcion del uruguay
# Processing Record 38 of Set 7 | mandalgovi
# Processing Record 39 of Set 7 | itoman
# Processing Record 40 of Set 7 | haimen
# Processing Record 41 of Set 7 | shibetsu
# Processing Record 42 of Set 7 | ocos
# Processing Record 43 of Set 7 | bengkulu
# Processing Record 44 of Set 7 | jacqueville
# Processing Record 45 of Set 7 | merauke
# Processing Record 46 of Set 7 | kilindoni
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | calama
# Processing Record 50 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 8 | batemans bay
# Processing Record 2 of Set 8 | guadix
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | charlottesville
# Processing Record 6 of Set 8 | waitati
# Processing Record 7 of Set 8 | udimskiy
# Processing Record 8 of Set 8 | de aar
# Processing Record 9 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 10 of Set 8 | lorengau
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | carutapera
# Processing Record 13 of Set 8 | kapenguria
# Processing Record 14 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 15 of Set 8 | san policarpo
# Processing Record 16 of Set 8 | mazagao
# Processing Record 17 of Set 8 | nemuro
# Processing Record 18 of Set 8 | comodoro rivadavia
# Processing Record 19 of Set 8 | sao filipe
# Processing Record 20 of Set 8 | taman
# Processing Record 21 of Set 8 | betare oya
# Processing Record 22 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 23 of Set 8 | inongo
# Processing Record 24 of Set 8 | tomatlan
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | otane
# Processing Record 27 of Set 8 | alugan
# Processing Record 28 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 29 of Set 8 | talara
# Processing Record 30 of Set 8 | ust-nera
# Processing Record 31 of Set 8 | girne
# Processing Record 32 of Set 8 | grand gaube
# Processing Record 33 of Set 8 | balkanabat
# Processing Record 34 of Set 8 | nokaneng
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | chokurdakh
# Processing Record 37 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 8 | bilibino
# Processing Record 39 of Set 8 | endicott
# Processing Record 40 of Set 8 | baykit
# Processing Record 41 of Set 8 | kargasok
# Processing Record 42 of Set 8 | zonguldak
# Processing Record 43 of Set 8 | jalingo
# Processing Record 44 of Set 8 | lima
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | goderich
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | mayor pablo lagerenza
# Processing Record 49 of Set 8 | bull savanna
# Processing Record 50 of Set 8 | boa vista
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | northam
# Processing Record 3 of Set 9 | zhangjiakou
# Processing Record 4 of Set 9 | apulia
# Processing Record 5 of Set 9 | geraldton
# Processing Record 6 of Set 9 | jacareacanga
# Processing Record 7 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 9 | srednekolymsk
# Processing Record 9 of Set 9 | alta floresta
# Processing Record 10 of Set 9 | snezhnogorsk
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | breytovo
# Processing Record 13 of Set 9 | salinopolis
# Processing Record 14 of Set 9 | campbell river
# Processing Record 15 of Set 9 | rocha
# Processing Record 16 of Set 9 | atar
# Processing Record 17 of Set 9 | qaqortoq
# Processing Record 18 of Set 9 | thinadhoo
# Processing Record 19 of Set 9 | santa cruz
# Processing Record 20 of Set 9 | turriff
# Processing Record 21 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 9 | inyonga
# Processing Record 23 of Set 9 | tuktoyaktuk
# Processing Record 24 of Set 9 | voi
# Processing Record 25 of Set 9 | sioux lookout
# Processing Record 26 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 9 | alencon
# Processing Record 28 of Set 9 | uniontown
# Processing Record 29 of Set 9 | andros town
# Processing Record 30 of Set 9 | temple
# Processing Record 31 of Set 9 | mhlambanyatsi
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | kununurra
# Processing Record 34 of Set 9 | roald
# Processing Record 35 of Set 9 | keetmanshoop
# Processing Record 36 of Set 9 | vigrestad
# Processing Record 37 of Set 9 | ouadda
# Processing Record 38 of Set 9 | ibresi
# Processing Record 39 of Set 9 | safford
# Processing Record 40 of Set 9 | praia da vitoria
# Processing Record 41 of Set 9 | pozo colorado
# Processing Record 42 of Set 9 | sola
# Processing Record 43 of Set 9 | conway
# Processing Record 44 of Set 9 | kondoa
# Processing Record 45 of Set 9 | veseloyarsk
# Processing Record 46 of Set 9 | povenets
# Processing Record 47 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 9 | narsaq
# Processing Record 49 of Set 9 | huarmey
# Processing Record 50 of Set 9 | bogo
# Processing Record 1 of Set 10 | beruni
# City not found. Skipping...
# Processing Record 2 of Set 10 | la cruz
# Processing Record 3 of Set 10 | tighina
# Processing Record 4 of Set 10 | drayton valley
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | kencong
# Processing Record 7 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 10 | adre
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | avera
# Processing Record 11 of Set 10 | muromtsevo
# Processing Record 12 of Set 10 | kuala selangor
# Processing Record 13 of Set 10 | olafsvik
# Processing Record 14 of Set 10 | aksay
# Processing Record 15 of Set 10 | viedma
# Processing Record 16 of Set 10 | beringovskiy
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | gatesville
# Processing Record 19 of Set 10 | nome
# Processing Record 20 of Set 10 | goure
# Processing Record 21 of Set 10 | mapiri
# Processing Record 22 of Set 10 | broome
# Processing Record 23 of Set 10 | chapais
# Processing Record 24 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 10 | ullapool
# Processing Record 26 of Set 10 | houma
# Processing Record 27 of Set 10 | tias
# Processing Record 28 of Set 10 | kerman
# Processing Record 29 of Set 10 | shieli
# Processing Record 30 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 10 | mumford
# Processing Record 32 of Set 10 | tateyama
# Processing Record 33 of Set 10 | bukachacha
# Processing Record 34 of Set 10 | moa
# Processing Record 35 of Set 10 | nova gradiska
# Processing Record 36 of Set 10 | virginia beach
# Processing Record 37 of Set 10 | la rioja
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | makakilo city
# Processing Record 40 of Set 10 | burica
# City not found. Skipping...
# Processing Record 41 of Set 10 | martin
# Processing Record 42 of Set 10 | hattiesburg
# Processing Record 43 of Set 10 | paita
# Processing Record 44 of Set 10 | kemijarvi
# Processing Record 45 of Set 10 | fort nelson
# Processing Record 46 of Set 10 | wetzlar
# Processing Record 47 of Set 10 | japura
# Processing Record 48 of Set 10 | dole
# Processing Record 49 of Set 10 | la ronge
# Processing Record 50 of Set 10 | asau
# Processing Record 1 of Set 11 | suntar
# Processing Record 2 of Set 11 | port hardy
# Processing Record 3 of Set 11 | asyut
# Processing Record 4 of Set 11 | sagarejo
# Processing Record 5 of Set 11 | bubaque
# Processing Record 6 of Set 11 | praya
# Processing Record 7 of Set 11 | mendi
# Processing Record 8 of Set 11 | kamenskiy
# Processing Record 9 of Set 11 | idenao
# Processing Record 10 of Set 11 | hudiksvall
# Processing Record 11 of Set 11 | saint-joseph
# Processing Record 12 of Set 11 | natal
# Processing Record 13 of Set 11 | neryungri
# Processing Record 14 of Set 11 | novyy buh
# Processing Record 15 of Set 11 | bolivar
# Processing Record 16 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 11 | pestovo
# Processing Record 18 of Set 11 | kuruman
# Processing Record 19 of Set 11 | montrose
# Processing Record 20 of Set 11 | sao joao da barra
# Processing Record 21 of Set 11 | akyab
# Processing Record 22 of Set 11 | kampong cham
# Processing Record 23 of Set 11 | mabay
# Processing Record 24 of Set 11 | tautira
# Processing Record 25 of Set 11 | chuy
# Processing Record 26 of Set 11 | loding
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | warrnambool
# Processing Record 29 of Set 11 | belyy yar
# Processing Record 30 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | tarakan
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | jibuti
# Processing Record 35 of Set 11 | thanh hoa
# Processing Record 36 of Set 11 | garissa
# Processing Record 37 of Set 11 | koslan
# Processing Record 38 of Set 11 | milkovo
# Processing Record 39 of Set 11 | hervey bay
# Processing Record 40 of Set 11 | koumra
# Processing Record 41 of Set 11 | zhezkazgan
# Processing Record 42 of Set 11 | puerto ayacucho
# Processing Record 43 of Set 11 | contamana
# Processing Record 44 of Set 11 | dutlwe
# Processing Record 45 of Set 11 | sangar
# Processing Record 46 of Set 11 | christchurch
# Processing Record 47 of Set 11 | altamont
# Processing Record 48 of Set 11 | escarcega
# Processing Record 49 of Set 11 | ponta delgada
# Processing Record 50 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 1 of Set 12 | camana
# Processing Record 2 of Set 12 | cidreira
# Processing Record 3 of Set 12 | quezon
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | inirida
# Processing Record 6 of Set 12 | sabya
# Processing Record 7 of Set 12 | jucurutu
# Processing Record 8 of Set 12 | gohad
# Processing Record 9 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 12 | hasaki
# Processing Record 11 of Set 12 | zyryanka
# Processing Record 12 of Set 12 | attingal
# Processing Record 13 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 12 | sembe
# Processing Record 16 of Set 12 | olinda
# Processing Record 17 of Set 12 | nipawin
# Processing Record 18 of Set 12 | medicine hat
# Processing Record 19 of Set 12 | sao gabriel da cachoeira
# Processing Record 20 of Set 12 | peleduy
# Processing Record 21 of Set 12 | tinyahuarco
# Processing Record 22 of Set 12 | lanzhou
# Processing Record 23 of Set 12 | galle
# Processing Record 24 of Set 12 | stornoway
# Processing Record 25 of Set 12 | tromso
# Processing Record 26 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 12 | porto velho
# Processing Record 29 of Set 12 | veraval
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | fare
# Processing Record 32 of Set 12 | xai-xai
# Processing Record 33 of Set 12 | omboue
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | port hueneme
# Processing Record 36 of Set 12 | mabaruma
# Processing Record 37 of Set 12 | saint-francois
# Processing Record 38 of Set 12 | grand forks
# Processing Record 39 of Set 12 | raudeberg
# Processing Record 40 of Set 12 | lock haven
# Processing Record 41 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 12 | srikakulam
# Processing Record 43 of Set 12 | nabire
# Processing Record 44 of Set 12 | nathdwara
# Processing Record 45 of Set 12 | dicabisagan
# Processing Record 46 of Set 12 | inta
# Processing Record 47 of Set 12 | langsa
# Processing Record 48 of Set 12 | tilichiki
# Processing Record 49 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 12 | abu dhabi
# Processing Record 1 of Set 13 | wamba
# Processing Record 2 of Set 13 | pilar
# Processing Record 3 of Set 13 | ishigaki
# Processing Record 4 of Set 13 | arawa
# Processing Record 5 of Set 13 | kaeo
# Processing Record 6 of Set 13 | fukuma
# Processing Record 7 of Set 13 | oytal
# Processing Record 8 of Set 13 | faya
# Processing Record 9 of Set 13 | la tuque
# Processing Record 10 of Set 13 | odweyne
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | alzamay
# Processing Record 13 of Set 13 | svetlyy
# Processing Record 14 of Set 13 | morogoro
# Processing Record 15 of Set 13 | lisakovsk
# Processing Record 16 of Set 13 | kahului
# Processing Record 17 of Set 13 | miaray
# Processing Record 18 of Set 13 | suhbaatar
# Processing Record 19 of Set 13 | necochea
# Processing Record 20 of Set 13 | brae
# Processing Record 21 of Set 13 | nishihara
# Processing Record 22 of Set 13 | manyana
# Processing Record 23 of Set 13 | cairns
# Processing Record 24 of Set 13 | oruro
# Processing Record 25 of Set 13 | sarahan
# Processing Record 26 of Set 13 | ventanas
# Processing Record 27 of Set 13 | mantua
# Processing Record 28 of Set 13 | bonthe
# Processing Record 29 of Set 13 | ransang
# Processing Record 30 of Set 13 | yining
# Processing Record 31 of Set 13 | poum
# Processing Record 32 of Set 13 | wick
# Processing Record 33 of Set 13 | karlshamn
# Processing Record 34 of Set 13 | san-pedro
# Processing Record 35 of Set 13 | esna
# Processing Record 36 of Set 13 | soe
# Processing Record 37 of Set 13 | puerto escondido
# Processing Record 38 of Set 13 | helena
# Processing Record 39 of Set 13 | sao francisco de assis
# Processing Record 40 of Set 13 | port-gentil
# Processing Record 41 of Set 13 | lucea
# Processing Record 42 of Set 13 | odienne
# Processing Record 43 of Set 13 | larsnes
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | fukue
# Processing Record 46 of Set 13 | miri
# Processing Record 47 of Set 13 | akdepe
# Processing Record 48 of Set 13 | myaundzha
# Processing Record 49 of Set 13 | yantal
# Processing Record 50 of Set 13 | ust-tsilma
# Processing Record 1 of Set 14 | minsk
# Processing Record 2 of Set 14 | ulladulla
# Processing Record 3 of Set 14 | yuanli
# Processing Record 4 of Set 14 | kalemie
# Processing Record 5 of Set 14 | tambacounda
# Processing Record 6 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 7 of Set 14 | auchel
# Processing Record 8 of Set 14 | at-bashi
# Processing Record 9 of Set 14 | kiama
# Processing Record 10 of Set 14 | madang
# Processing Record 11 of Set 14 | llanes
# Processing Record 12 of Set 14 | agadir
# Processing Record 13 of Set 14 | tenenkou
# Processing Record 14 of Set 14 | paraiso
# Processing Record 15 of Set 14 | bhongir
# Processing Record 16 of Set 14 | sur
# Processing Record 17 of Set 14 | progreso
# Processing Record 18 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 14 | beloha
# Processing Record 20 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 14 | solnechnyy
# Processing Record 22 of Set 14 | namibe
# Processing Record 23 of Set 14 | rio grande
# Processing Record 24 of Set 14 | kandrian
# Processing Record 25 of Set 14 | moron
# Processing Record 26 of Set 14 | ariquemes
# Processing Record 27 of Set 14 | tuensang
# Processing Record 28 of Set 14 | yurga
# Processing Record 29 of Set 14 | sao desiderio
# Processing Record 30 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 14 | mwene-ditu
# Processing Record 32 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 33 of Set 14 | raga
# Processing Record 34 of Set 14 | cartagena
# Processing Record 35 of Set 14 | aksarka
# Processing Record 36 of Set 14 | chernushka
# Processing Record 37 of Set 14 | aleksandrov gay
# Processing Record 38 of Set 14 | el retorno
# Processing Record 39 of Set 14 | puerto cabezas
# Processing Record 40 of Set 14 | shirvan
# Processing Record 41 of Set 14 | seoul
# Processing Record 42 of Set 14 | bandarbeyla
# Processing Record 43 of Set 14 | santa cruz de la palma
# Processing Record 44 of Set 14 | aksu
# Processing Record 45 of Set 14 | hailar
# Processing Record 46 of Set 14 | tandil
# Processing Record 47 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 14 | north battleford
# Processing Record 49 of Set 14 | maarianhamina
# Processing Record 50 of Set 14 | miles city
# Processing Record 1 of Set 15 | shenzhen
# Processing Record 2 of Set 15 | alexandria
# Processing Record 3 of Set 15 | arrecife
# Processing Record 4 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 15 | kibala
# Processing Record 6 of Set 15 | sikea
# City not found. Skipping...
# Processing Record 7 of Set 15 | namatanai
# Processing Record 8 of Set 15 | bintulu
# Processing Record 9 of Set 15 | aripuana
# Processing Record 10 of Set 15 | denizli
# Processing Record 11 of Set 15 | marsa matruh
# Processing Record 12 of Set 15 | mackay
# Processing Record 13 of Set 15 | balarampur
# Processing Record 14 of Set 15 | tamandare
# Processing Record 15 of Set 15 | santa maria
# Processing Record 16 of Set 15 | san cristobal
# Processing Record 17 of Set 15 | ambovombe
# Processing Record 18 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 19 of Set 15 | clute
# Processing Record 20 of Set 15 | adrar
# Processing Record 21 of Set 15 | churapcha
# Processing Record 22 of Set 15 | capao da canoa
# Processing Record 23 of Set 15 | havre-saint-pierre
# Processing Record 24 of Set 15 | satipo
# Processing Record 25 of Set 15 | portland
# Processing Record 26 of Set 15 | tokur
# Processing Record 27 of Set 15 | xinzhou
# Processing Record 28 of Set 15 | fairbanks
# Processing Record 29 of Set 15 | acarau
# Processing Record 30 of Set 15 | sao luiz gonzaga
# Processing Record 31 of Set 15 | hovin
# Processing Record 32 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 33 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 15 | jinchang
# Processing Record 35 of Set 15 | collie
# Processing Record 36 of Set 15 | bongandanga
# Processing Record 37 of Set 15 | renqiu
# Processing Record 38 of Set 15 | am timan
# Processing Record 39 of Set 15 | kurilsk
# Processing Record 40 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 15 | ninh binh
# Processing Record 42 of Set 15 | dedougou
# Processing Record 43 of Set 15 | naze
# Processing Record 44 of Set 15 | karratha
# Processing Record 45 of Set 15 | taoudenni
# Processing Record 46 of Set 15 | kiruna
# Processing Record 47 of Set 15 | falam
# Processing Record 48 of Set 15 | sao geraldo do araguaia
# Processing Record 49 of Set 15 | dalianwan
# Processing Record 50 of Set 15 | emet
# Processing Record 1 of Set 16 | balvi
# Processing Record 2 of Set 16 | manta
# Processing Record 3 of Set 16 | toccoa
# Processing Record 4 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 16 | sobolevo
# Processing Record 6 of Set 16 | piet retief
# Processing Record 7 of Set 16 | muros
# Processing Record 8 of Set 16 | onguday
# Processing Record 9 of Set 16 | ye
# City not found. Skipping...
# Processing Record 10 of Set 16 | bundaberg
# Processing Record 11 of Set 16 | lazaro cardenas
# Processing Record 12 of Set 16 | tarquinia
# Processing Record 13 of Set 16 | margate
# Processing Record 14 of Set 16 | doha
# Processing Record 15 of Set 16 | deep river
# Processing Record 16 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 16 | balikpapan
# Processing Record 18 of Set 16 | bridlington
# Processing Record 19 of Set 16 | lincoln
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown   5.4112  100.3354     89.60        55          20
# 1           Touba   8.2833   -7.6833     74.91        80         100
# 2         Mataura -46.1927  168.8643     55.99        80           0
# 3  Saint-Philippe -21.3585   55.7679     84.20        65          20
# 4        Pochutla  15.7432  -96.4661     70.00        83           0
# 5        Dongzhen  22.3797  110.9389     89.01        66          83
# 6      Vila Velha -20.3297  -40.2925     78.01        94           0
# 7      Bredasdorp -34.5322   20.0403     75.20        57          20
# 8       Saskylakh  71.9167  114.0833    -16.87        92         100
# 9       Esperance -33.8667  121.9000     89.60        22           0
#
#    Wind Speed Country Current Description
# 0       12.66      MY          few clouds
# 1        7.67      CI     overcast clouds
# 2        1.01      NZ           clear sky
# 3       19.57      RE          few clouds
# 4        2.89      MX           clear sky
# 5       12.06      CN       broken clouds
# 6        1.14      BR           clear sky
# 7        5.75      ZA          few clouds
# 8        5.77      RU     overcast clouds
# 9       17.27      AU           clear sky

# %%
# Change column orders
new_column_order = ["City", "Country","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown      MY   5.4112  100.3354     89.60        55          20
# 1           Touba      CI   8.2833   -7.6833     74.91        80         100
# 2         Mataura      NZ -46.1927  168.8643     55.99        80           0
# 3  Saint-Philippe      RE -21.3585   55.7679     84.20        65          20
# 4        Pochutla      MX  15.7432  -96.4661     70.00        83           0
# 5        Dongzhen      CN  22.3797  110.9389     89.01        66          83
# 6      Vila Velha      BR -20.3297  -40.2925     78.01        94           0
# 7      Bredasdorp      ZA -34.5322   20.0403     75.20        57          20
# 8       Saskylakh      RU  71.9167  114.0833    -16.87        92         100
# 9       Esperance      AU -33.8667  121.9000     89.60        22           0
#
#    Wind Speed Current Description
# 0       12.66          few clouds
# 1        7.67     overcast clouds
# 2        1.01           clear sky
# 3       19.57          few clouds
# 4        2.89           clear sky
# 5       12.06       broken clouds
# 6        1.14           clear sky
# 7        5.75          few clouds
# 8        5.77     overcast clouds
# 9       17.27           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
